# %%
# Import required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from imblearn.over_sampling import SMOTE
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, accuracy_score, classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
import pickle
import warnings
warnings.filterwarnings("ignore")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\acar\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\acar\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\acar\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
# ...

# %%
df = pd.read_csv("telecom_customer_churn.csv")

# %%
pd.set_option("display.max_columns", None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pd.set_option("display.max_columns", None)
#
# NameError: name 'pd' is not defined

# %%
df.shape
# Out:
# (6588, 33)

# %%
df.head(5)
# Out:
#     viewer_id  gender  age married  number_of_family_dependents city  \
# 0  0002-ORFBO  Female   37     Yes                            0   SD
# 1  0003-MKNFE    Male   46      No                            0   SD
# 2  0004-TLHLJ    Male   50      No                            0   SD
# 3  0011-IGKFF    Male   78     Yes                            0   SD
# 4  0013-EXCHZ  Female   75     Yes                            0   SD
#
#    zip_code   latitude   longitude  number_of_referrals  tenure_in_months  \
# 0     93225  34.827662 -118.999073                    2                 9
# 1     91206  34.162515 -118.203869                    0                 9
# 2     92627  33.645672 -117.922613                    0                 4
# 3     94553  38.014457 -122.115432                    1                13
# 4     93010  34.227846 -119.079903                    3                 3
#
#      offer internet_service internet_type  avg_monthly_gb_download  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6588 entries, 0 to 6587
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   viewer_id                    6588 non-null   object
#  1   gender                       6588 non-null   object
#  2   age                          6588 non-null   int64
#  3   married                      6588 non-null   object
#  4   number_of_family_dependents  6588 non-null   int64
#  5   city                         6588 non-null   object
#  6   zip_code                     6588 non-null   int64
#  7   latitude                     6588 non-null   float64
#  8   longitude                    6588 non-null   float64
#  9   number_of_referrals          6588 non-null   int64
#  10  tenure_in_months             6588 non-null   int64
#  11  offer                        2990 non-null   object
#  12  internet_service             6588 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# viewer_id                         0
# gender                            0
# age                               0
# married                           0
# number_of_family_dependents       0
# city                              0
# zip_code                          0
# latitude                          0
# longitude                         0
# number_of_referrals               0
# tenure_in_months                  0
# offer                          3598
# internet_service                  0
# internet_type                  1344
# avg_monthly_gb_download        1344
# online_security                1344
# online_backup                  1344
# device_protection_plan         1344
# premium_tech_support           1344
# streaming_tv                   1344
# streaming_movies               1344
# streaming_music                1344
# unlimited_hi-res_streaming     1344
# subscription_type                 0
# paperless_billing                 0
# payment_method                    0
# ...

# %%
# dropping unnecessary columns
columns_to_drop = ["zip_code","viewer_id", "latitude", "longitude", "city", "offer"]

df_2 = df.drop(columns= columns_to_drop, axis=1)

# %%
df_2.head(5)
# Out:
#    gender  age married  number_of_family_dependents  number_of_referrals  \
# 0  Female   37     Yes                            0                    2
# 1    Male   46      No                            0                    0
# 2    Male   50      No                            0                    0
# 3    Male   78     Yes                            0                    1
# 4  Female   75     Yes                            0                    3
#
#    tenure_in_months internet_service internet_type  avg_monthly_gb_download  \
# 0                 9              Yes         Cable                     16.0
# 1                 9              Yes         Cable                     10.0
# 2                 4              Yes   Fiber Optic                     30.0
# 3                13              Yes   Fiber Optic                      4.0
# 4                 3              Yes   Fiber Optic                     11.0
#
# ...

# %%
df_2.shape
# Out:
# (6588, 27)

# %%
# handling missing value
df_2['avg_monthly_gb_download'] = df_2["avg_monthly_gb_download"].fillna(df_2["avg_monthly_gb_download"]).median()

df_2['internet_type'] = df_2['internet_type'].fillna(df_2['internet_type']).mode()[0]

cols_to_fill = ['online_security', 'online_backup', 'device_protection_plan', 'premium_tech_support', 'streaming_tv',
                'streaming_movies', 'streaming_music', 'unlimited_hi-res_streaming']
df_2[cols_to_fill] = df_2[cols_to_fill].fillna('No')

# %%
df_2.isnull().sum()
# Out:
# gender                         0
# age                            0
# married                        0
# number_of_family_dependents    0
# number_of_referrals            0
# tenure_in_months               0
# internet_service               0
# internet_type                  0
# avg_monthly_gb_download        0
# online_security                0
# online_backup                  0
# device_protection_plan         0
# premium_tech_support           0
# streaming_tv                   0
# streaming_movies               0
# streaming_music                0
# unlimited_hi-res_streaming     0
# subscription_type              0
# paperless_billing              0
# payment_method                 0
# monthly_charge                 0
# total_charges                  0
# total_refunds                  0
# total_extra_data_charges       0
# total_long_distance_charges    0
# total_revenue                  0
# viewer_status                  0
# dtype: int64

# %%
# ting unique values in the columns
num_col = ['age', 'total_revenue', 'total_refunds', 'total_long_distance_charges', 'total_extra_data_charges', 'total_charges', 'monthly_charge', 'tenure_in_months']

for col in df_2.columns:
    if col not in num_col:
        print(col, df_2[col].unique())
        print("-"*60)
# Out:
# gender ['Female' 'Male']
# ------------------------------------------------------------
# married ['Yes' 'No']
# ------------------------------------------------------------
# number_of_family_dependents [0 3 1 2 4 6 5 9 7 8]
# ------------------------------------------------------------
# number_of_referrals [ 2  0  1  3  8  9 10  5  4  7  6 11]
# ------------------------------------------------------------
# internet_service ['Yes' 'No']
# ------------------------------------------------------------
# internet_type ['Fiber Optic']
# ------------------------------------------------------------
# avg_monthly_gb_download [21.]
# ------------------------------------------------------------
# online_security ['No' 'Yes']
# ------------------------------------------------------------
# online_backup ['Yes' 'No']
# ------------------------------------------------------------
# device_protection_plan ['No' 'Yes']
# ------------------------------------------------------------
# ...

# %%
df_2.viewer_status.value_counts()
# Out:
# viewer_status
# Stayed     4719
# Churned    1869
# Name: count, dtype: int64

# %%
df_2.viewer_status.value_counts(normalize = True)
# Out:
# viewer_status
# Stayed     0.716302
# Churned    0.283698
# Name: proportion, dtype: float64

# %%
plt.figure(figsize = (6,4))
sns.countplot(x="viewer_status", data=df_2)
plt.title("Distribution of Customers")
plt.xticks([0,1], ["stayed (0)", "churned (1)"])
plt.xlabel("Churn")
plt.ylabel("No. of Customers")
plt.show()

# %%
def plot_histogram(df, columns_name):
    
    plt.figure(figsize = (5,3))
    sns.histplot(df[columns_name], kde=True)
    plt.title(f"Dustribution of {columns_name}")

    # Calculate the mean and median values for the columns
    col_mean = df[columns_name].mean()
    col_median = df[columns_name].median()
    
    #add vertical lines for mean and median
    plt.axvline(col_mean, color="red", linestyle="--", label="mean")
    plt.axvline(col_median, color="green", linestyle="-", label="median")
    
    plt.legend()
    plt.show()

# %%
plot_histogram(df,"total_charges")
plot_histogram(df,"tenure_in_months")
plot_histogram(df,"monthly_charge")

# %%
def box_plot(df, columns_name):
    plt.figure(figsize = (5,3))
    sns.boxplot(y = df[columns_name])
    plt.title(f"Boxplot of {columns_name}")
    plt.ylabel(columns_name)
    plt.show()

# %%
box_plot(df,"total_charges")
box_plot(df,"tenure_in_months")
box_plot(df,"monthly_charge")

# %%
# Converting the predictor variable in a binary numeric variable
df_2['viewer_status'].replace({"Stayed": 1, "Churned": 0}, inplace=True)

# %% [raw]
# Label encoding of categorical features

# %%
# identifying columna with object data types
object_columns = df_2.select_dtypes(include='object').columns

# %%
print(object_columns)
# Out:
# Index(['gender', 'married', 'internet_service', 'internet_type',
#        'online_security', 'online_backup', 'device_protection_plan',
#        'premium_tech_support', 'streaming_tv', 'streaming_movies',
#        'streaming_music', 'unlimited_hi-res_streaming', 'subscription_type',
#        'paperless_billing', 'payment_method'],
#       dtype='object')

# %%
# initialize a dictionary to save the encoders
encoders = {}

# apply label encoding and store the encoders 
for columns in object_columns:
    label_encoder = LabelEncoder()
    df_2[columns] = label_encoder.fit_transform(df_2[columns])
    encoders[columns] = label_encoder

    # save yje encoders to a pickle file
    with open("encoders.pkl", "wb") as f:
        pickle.dump(encoders, f)

# %%
df_2
# Out:
#       gender  age  married  number_of_family_dependents  number_of_referrals  \
# 0          0   37        1                            0                    2
# 1          1   46        0                            0                    0
# 2          1   50        0                            0                    0
# 3          1   78        1                            0                    1
# 4          0   75        1                            0                    3
# ...      ...  ...      ...                          ...                  ...
# 6583       0   36        0                            0                    0
# 6584       0   20        0                            0                    0
# 6585       1   40        1                            0                    1
# 6586       1   21        1                            0                    5
# 6587       1   36        1                            0                    1
#
# ...

# %%
#Get Correlation of "Churn" with other variables:
corr = df_2.corr()['viewer_status'].drop('viewer_status').sort_values()

plt.figure(figsize=(8,8))
corr.plot(kind='barh', color='teal')
plt.title('Features Correlation with viewer_status')
plt.xlabel("correlation with viewer_status")
plt.grid(True, linestyle = '--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# dropping weak corelated columns
df_2 = df_2.drop(columns=["total_refunds", "gender", "total_extra_data_charges", "streaming_tv", "streaming_music", "streaming_movies"], axis=1)

# %%
df_2.shape
# Out:
# (6588, 21)

# %%
# Selected features based on Strongest Positive and Strongest Negative correlations with viewer_status
selected_feature = ["subscription_type", "tenure_in_months", "number_of_referrals", "total_revenue", #strong poaitive
                   "internet_service", "paperless_billing","monthly_charge", "unlimited_hi-res_streaming"] #strong negative

plt.figure(figsize=(15, 12))
for i, features in enumerate(selected_feature, 1):
    plt.subplot(3,4,i)
    sns.boxplot(data=df_2, x='viewer_status', y=features, palette='coolwarm')
    plt.title(f'Distribution of {features} by Status')

plt.tight_layout()
plt.show()

# %% [raw]
# Training and Test data split

# %%
x = df_2.drop(columns = ["viewer_status"])
y = df_2.viewer_status

# %%
# spliting train and test data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
y_train.value_counts()
# Out:
# viewer_status
# 1    3770
# 0    1500
# Name: count, dtype: int64

# %% [raw]
# Balancing data using SMOTE

# %%
smote = SMOTE(random_state = 42)

# %%
x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

# %%
y_train_smote.value_counts()
# Out:
# viewer_status
# 1    3770
# 0    3770
# Name: count, dtype: int64

# %% [raw]
# Training with default hyperparameter

# %%
# dictionary of meodels
models = {
    "Dicision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "XGBoost": XGBClassifier(random_state=42)
}

# %%
# dictionary to store the cross validation results 
cv_scores = {}

# performs 5-fold coross validation for each model
for model_name, model in models.items():
    print(f"Training {model_name} with default parameters")
    scores = cross_val_score(model, x_train_smote, y_train_smote, cv=5, scoring="accuracy")
    cv_scores[model_name] = scores
    print(f"{model_name} cross-validation accuracy: {np.mean(scores):.2f}")
    print("-"*70)
# Out:
# Training Dicision Tree with default parameters
# Dicision Tree cross-validation accuracy: 0.84
# ----------------------------------------------------------------------
# Training Random Forest with default parameters
# Random Forest cross-validation accuracy: 0.89
# ----------------------------------------------------------------------
# Training XGBoost with default parameters
# XGBoost cross-validation accuracy: 0.89
# ----------------------------------------------------------------------

# %% [raw]
# Random Forest gives the highest accuracy comapred to other models with defaul parameters

# %%
rfc = RandomForestClassifier(random_state=42)

# %%
rfc.fit(x_train_smote, y_train_smote)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# # Model Evaluation

# %%
# evaluate on test data 
y_test_pred = rfc.predict(x_test)

print("Accuracy of Score:\n", accuracy_score(y_test, y_test_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred))
print("Classification Report:\n", classification_report(y_test, y_test_pred))
# Out:
# Accuracy of Score:
#  0.866464339908953
# Confusion Matrix:
#  [[289  80]
#  [ 96 853]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.78      0.77       369
#            1       0.91      0.90      0.91       949
#
#     accuracy                           0.87      1318
#    macro avg       0.83      0.84      0.84      1318
# weighted avg       0.87      0.87      0.87      1318
